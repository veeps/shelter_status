# %%
# Installing requirements 
# !pip install pyquery
# !pip install -r './assets/got_requirements.txt'
# !pip install langdetect

# %%
import pandas as pd
import time
import GetOldTweets3 as got
from langdetect import detect

# %% [markdown]
# ## Create function to get tweets from multiple users

# %%
def get_tweets(users, since_date, until_date, num_tweets):
    '''
    Pulls tweets from multiple users and returns a pandas dataframe.
    Index: date
    Columns: text, username
    ---
    users: List of usernames without the '@' sign
    since_date: Date that to start pulling tweets. Input as string "YYYY-MM-DD"
    until_date: Date that to tweets go up to. Input as string "YYYY-MM-DD"
    num_tweets: Int. Total number of tweets to pull per user
    '''
    all_tweets = pd.DataFrame()
    for user in users:
        tweetCriteria = got.manager.TweetCriteria().setUsername(user).setSince(since_date).setUntil(until_date).setMaxTweets(num_tweets)
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        df = tweets_to_df(tweets)
        all_tweets = pd.concat([all_tweets,df])
    
    all_tweets["language"] = all_tweets["text"].apply(detect)
        
    return all_tweets

# %% [markdown]
# ## Create function to convert tweets to dataframe

# %%
# This code was adapted from Ritchie Kwan's project
# https://github.com/rkkwan/disaster-rapid-alert/blob/master/code/01-Gathering-Data.ipynb
def tweets_to_df(tweets):
    '''
    Converts tweets in acquired using GOT into a Pandas dataframe.
    Index: date
    Columns: text
    '''
    tweets_list = []
    for t in tweets:
        tweet_dict = {}
        tweet_dict['date'] = t.date
        tweet_dict['text'] = t.text
        tweet_dict['user'] = t.username
        tweets_list.append(tweet_dict)
        
    tweets_df = pd.DataFrame(tweets_list)
    
    # convert to time series
    tweets_df.set_index(tweets_df['date'], inplace = True)
    tweets_df.sort_index(ascending = True)
    
    return tweets_df[["text", "user"]]

# %% [markdown]
# ## Get tweets

# %%
# list of users to pull tweets from
users=["CountyofSonoma", "create_self"]
sample_tweets = get_tweets(users, "2019-10-23", "2019-11-06", 50)

# %%
# filter for tweets in English
english_tweets = sample_tweets[sample_tweets["language"] == "en"]

# %%
english_tweets
# Out:
#                                                                         text  \
# date
# 2019-11-05 22:38:37+00:00  @SoCoPRMD is conducting damage assessments on ...
# 2019-11-05 20:13:58+00:00  The current wait time at the Local Assistance ...
# 2019-11-05 18:50:32+00:00  The Local Assistance Center is open again toda...
# 2019-11-05 03:40:04+00:00  During a disaster, it’s common to have increas...
# 2019-11-05 02:30:04+00:00  The county Human Services Dept is offering ass...
# 2019-11-05 01:45:03+00:00  If you are a business owner or employee of a b...
# 2019-11-05 01:03:58+00:00  Our Local Assistance Center is open at the Hea...
# 2019-11-04 23:15:49+00:00  As of 3 p.m., ALL evacuation warnings have bee...
# 2019-11-04 19:24:46+00:00  INCENDIO KINCADE ACTUALIZACION DEL INCIDENTE 1...
# 2019-11-04 18:56:23+00:00  More info on the Local Assistance Center at ht...
# 2019-11-04 17:44:18+00:00                    #KincadeFire Update for 11.4.19
# 2019-11-04 04:00:06+00:00  Support victims with a financial donation, whi...
# 2019-11-04 03:00:06+00:00  During a disaster, it’s common to have increas...
# 2019-11-04 02:00:09+00:00  The county Human Services Dept is offering ass...
# 2019-11-04 01:00:08+00:00  If you are a business owner or employee of a b...
# 2019-11-04 00:52:05+00:00  The Local Assistance Center opens at 10 a.m. o...
# 2019-11-04 00:52:04+00:00  Re-Entry Only residents and business workers a...
# 2019-11-03 23:20:51+00:00  For up-to-date information on the #KincadeFire...
# 2019-11-03 23:20:51+00:00  As of 3 p.m., the Sonoma County Sheriff’s Offi...
# 2019-11-03 21:32:36+00:00  Residents impacted by the Kincade Fire: Access...
# 2019-11-03 19:12:08+00:00  For up to date school closures visit Sonoma Co...
# 2019-11-03 18:44:35+00:00  INCENDIO KINCADE ACTUALIZACION DEL INCIDENTE 1...
# 2019-11-01 18:01:05+00:00                     Lol... is this your place/!?!!
# 2019-10-31 06:04:12+00:00  Solid move, @Twitter. https://www.nytimes.com/...
# 2019-10-24 22:21:54+00:00  #lifegoals .. create stories as visually compe...
# 2019-10-23 18:30:04+00:00  Our healthcare system is a joke, and utterly i...
# 2019-10-23 18:22:47+00:00  Reclaming public ad spaces for advocacy needs....
#
#                                      user language
# date
# 2019-11-05 22:38:37+00:00  CountyofSonoma       en
# 2019-11-05 20:13:58+00:00  CountyofSonoma       en
# 2019-11-05 18:50:32+00:00  CountyofSonoma       en
# 2019-11-05 03:40:04+00:00  CountyofSonoma       en
# 2019-11-05 02:30:04+00:00  CountyofSonoma       en
# 2019-11-05 01:45:03+00:00  CountyofSonoma       en
# 2019-11-05 01:03:58+00:00  CountyofSonoma       en
# 2019-11-04 23:15:49+00:00  CountyofSonoma       en
# 2019-11-04 19:24:46+00:00  CountyofSonoma       en
# 2019-11-04 18:56:23+00:00  CountyofSonoma       en
# 2019-11-04 17:44:18+00:00  CountyofSonoma       en
# 2019-11-04 04:00:06+00:00  CountyofSonoma       en
# 2019-11-04 03:00:06+00:00  CountyofSonoma       en
# 2019-11-04 02:00:09+00:00  CountyofSonoma       en
# 2019-11-04 01:00:08+00:00  CountyofSonoma       en
# 2019-11-04 00:52:05+00:00  CountyofSonoma       en
# 2019-11-04 00:52:04+00:00  CountyofSonoma       en
# 2019-11-03 23:20:51+00:00  CountyofSonoma       en
# 2019-11-03 23:20:51+00:00  CountyofSonoma       en
# 2019-11-03 21:32:36+00:00  CountyofSonoma       en
# 2019-11-03 19:12:08+00:00  CountyofSonoma       en
# 2019-11-03 18:44:35+00:00  CountyofSonoma       en
# 2019-11-01 18:01:05+00:00     create_self       en
# 2019-10-31 06:04:12+00:00     create_self       en
# 2019-10-24 22:21:54+00:00     create_self       en
# 2019-10-23 18:30:04+00:00     create_self       en
# 2019-10-23 18:22:47+00:00     create_self       en
