# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201'}

# %%
pd.set_option('display.max_columns', 500)
lang= 'english'
limit = 30000

# %%
la_begin_date = dt.date(2018,8,1)
la_end_date = dt.date(2020,2,12)

# %%
tweets_la = query_tweets('louisiana floods need', begindate=la_begin_date, enddate=la_end_date,
                     limit=limit, lang=lang);

# %%
df_la=pd.DataFrame(t.__dict__ for t in tweets_la)

# %%
ne_begin_date = dt.date(2019,3,1)
ne_end_date = dt.date(2020,2,12)

# %%
tweets_ne = query_tweets('nebraska floods need', begindate=ne_begin_date, enddate=ne_end_date,
                     limit=limit, lang=lang);

# %%
df_ne=pd.DataFrame(t.__dict__ for t in tweets_ne)

# %%
ms_begin_date = dt.date(2018,12,1)
ms_end_date = dt.date(2020,2,12)

# %%
tweets_ms = query_tweets('mississippi floods need', begindate=ms_begin_date, enddate=ms_end_date,
                     limit=limit, lang=lang);

# %%
df_ms=pd.DataFrame(t.__dict__ for t in tweets_ms)

# %%
oh_begin_date = dt.date(2018,2,1)
oh_end_date = dt.date(2020,2,12)

# %%
tweets_oh = query_tweets('ohio floods need', begindate=oh_begin_date, enddate=oh_end_date,
                     limit=limit, lang=lang);

# %%
df_oh=pd.DataFrame(t.__dict__ for t in tweets_oh)

# %%
df_floods = pd.concat([df_la, df_ne, df_ms, df_oh])

# %%
df_floods['disaster']='floods'

# %%
df_floods.head(2)

# %%
df_floods.to_csv('df_floods.csv', index=False)

# %%
df_floods = pd.read_csv('../Data/df_floods.csv')

# %%
df_floods.drop(columns='Unnamed: 0', inplace=True)

# %%
df_floods.drop_duplicates(subset='text', keep='first', inplace=True)

# %%
custom_sw = stopwords.words('english')

# %%
additional_sw = []

# %%
for word in additional_sw:
    custom_sw.append(word)

# %%
tvec = TfidfVectorizer(stop_words=custom_sw, min_df=5, max_df=1.0)

# %%
term_mat = tvec.fit_transform(df_floods['text'])

# %%
term_df = pd.DataFrame(term_mat.toarray(), columns=tvec.get_feature_names())

# %%
tvec.get_feature_names()
# Out:
# ['000',
#  '03',
#  '05',
#  '10',
#  '100',
#  '11e9',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1927',
#  '20',
#  '200',
#  '2016',
#  '2018',
#  '2019',
#  '2020',
#  '29',
#  '5d1a',
#  '800',
#  'abf4',
#  'able',
#  'across',
#  'action',
#  'additional',
#  'affected',
#  'ago',
#  'ahead',
#  'aid',
#  'air',
#  'alert',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'always',
#  'amazing',
#  'america',
#  'american',
#  'americans',
#  'animal',
#  'animals',
#  'another',
#  'anyone',
#  'anything',
#  'anywhere',
#  'approach',
#  'area',
#  'areas',
#  'ark',
#  'army',
#  'around',
#  'article',
#  'article_9064ec14',
#  'ask',
#  'assist',
#  'assistance',
#  'attention',
#  'august',
#  'available',
#  'avoid',
#  'away',
#  'b1ad719a4f2c',
#  'b872',
#  'back',
#  'bad',
#  'bank',
#  'barry',
#  'begin',
#  'behind',
#  'benefits',
#  'better',
#  'big',
#  'bill',
#  'billion',
#  'bit',
#  'black',
#  'bless',
#  'blizzard',
#  'blue',
#  'bomb',
#  'break',
#  'breaking',
#  'bridges',
#  'bring',
#  'buff',
#  'build',
#  'building',
#  'business',
#  'california',
#  'call',
#  'calls',
#  'came',
#  'campus',
#  'car',
#  'care',
#  'caring',
#  'catastrophic',
#  'cause',
#  'caused',
#  'central',
#  'change',
#  'channel',
#  'check',
#  'children',
#  'church',
#  'churches',
#  'cities',
#  'citizens',
#  'city',
#  'clean',
#  'cleaning',
#  'click',
#  'climate',
#  'climatechange',
#  'close',
#  'closed',
#  'cnn',
#  'coast',
#  'com',
#  'come',
#  'coming',
#  'communities',
#  'community',
#  'conditions',
#  'consider',
#  'considered',
#  'contact',
#  'content',
#  'continue',
#  'control',
#  'could',
#  'counties',
#  'country',
#  'county',
#  'coverage',
#  'covering',
#  'crisis',
#  'crops',
#  'cross',
#  'cut',
#  'cyclone',
#  'dakota',
#  'dam',
#  'damage',
#  'damaged',
#  'damn',
#  'dams',
#  'dangerous',
#  'davenport',
#  'day',
#  'days',
#  'deal',
#  'dealing',
#  'dear',
#  'declare',
#  'delta',
#  'democrats',
#  'desperate',
#  'desperately',
#  'destroyed',
#  'destruction',
#  'devastated',
#  'devastating',
#  'devastation',
#  'disaster',
#  'disasters',
#  'displaced',
#  'donate',
#  'donated',
#  'donating',
#  'donation',
#  'donations',
#  'done',
#  'dont',
#  'drive',
#  'drown',
#  'dry',
#  'due',
#  'duplication',
#  'eagle',
#  'east',
#  'eastern',
#  'effect',
#  'efforts',
#  'else',
#  'emergency',
#  'end',
#  'engineers',
#  'enough',
#  'entire',
#  'environment',
#  'especially',
#  'etc',
#  'evacuate',
#  'even',
#  'event',
#  'events',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'example',
#  'facebook',
#  'fall',
#  'families',
#  'family',
#  'far',
#  'farm',
#  'farmer',
#  'farmers',
#  'farms',
#  'fbclid',
#  'federal',
#  'feed',
#  'feel',
#  'fellow',
#  'fema',
#  'fight',
#  'find',
#  'first',
#  'fix',
#  'flash',
#  'flood',
#  'flooded',
#  'flooding',
#  'floods',
#  'florida',
#  'focus',
#  'folks',
#  'following',
#  'food',
#  'force',
#  'forget',
#  'found',
#  'free',
#  'fremont',
#  'friday',
#  'friends',
#  'full',
#  'funding',
#  'fundraiser',
#  'future',
#  'get',
#  'gets',
#  'getting',
#  'give',
#  'giving',
#  'global',
#  'go',
#  'god',
#  'goes',
#  'gofundme',
#  'going',
#  'gone',
#  'gonna',
#  'good',
#  'got',
#  'gov',
#  'government',
#  'governor',
#  'great',
#  'green',
#  'ground',
#  'grow',
#  'guard',
#  'gulf',
#  'half',
#  'hand',
#  'happening',
#  'hard',
#  'hay',
#  'health',
#  'hear',
#  'heard',
#  'heartland',
#  'heavy',
#  'help',
#  'helping',
#  'helps',
#  'herald',
#  'hey',
#  'hi',
#  'high',
#  'higher',
#  'historic',
#  'hit',
#  'home',
#  'homeless',
#  'homes',
#  'hope',
#  'house',
#  'html',
#  'http',
#  'https',
#  'huge',
#  'hurricane',
#  'hurricanes',
#  'ia',
#  'ice',
#  'id',
#  'idea',
#  'ig_twitter_share',
#  'igshid',
#  'illegal',
#  'illinois',
#  'immediately',
#  'impacted',
#  'important',
#  'inches',
#  'including',
#  'info',
#  'information',
#  'infrastructure',
#  'instagram',
#  'insurance',
#  'iowa',
#  'island',
#  'issue',
#  'issued',
#  'issues',
#  'items',
#  'job',
#  'join',
#  'july',
#  'kansas',
#  'katrina',
#  'keep',
#  'kentucky',
#  'killing',
#  'kind',
#  'know',
#  'la',
#  'lake',
#  'land',
#  'last',
#  'late',
#  'law',
#  'learn',
#  'least',
#  'leaving',
#  'left',
#  'less',
#  'let',
#  'levee',
#  'levees',
#  'level',
#  'levels',
#  'life',
#  'like',
#  'lincoln',
#  'link',
#  'list',
#  'little',
#  'live',
#  'lives',
#  'livestock',
#  'living',
#  'local',
#  'long',
#  'longer',
#  'longest',
#  'look',
#  'looking',
#  'looks',
#  'loss',
#  'lost',
#  'lot',
#  'lots',
#  'louisiana',
#  'love',
#  'ly',
#  'm25m_org',
#  'made',
#  'major',
#  'make',
#  'man',
#  'management',
#  'many',
#  'march',
#  'massive',
#  'may',
#  'maybe',
#  'media',
#  'members',
#  'mental',
#  'middle',
#  'midwest',
#  'might',
#  'mighty',
#  'million',
#  'mississippi',
#  'missouri',
#  'mo',
#  'money',
#  'month',
#  'months',
#  'morning',
#  'move',
#  'moving',
#  'msnbc',
#  'much',
#  'name',
#  'nation',
#  'national',
#  'natural',
#  'nbcnews',
#  'ne',
#  'near',
#  'nebraska',
#  'nebraskaflood',
#  'nebraskaflood2019',
#  'nebraskaflooding',
#  'nebraskans',
#  'nebraskastrong',
#  'need',
#  'needed',
#  'needs',
#  'nefarmbureau',
#  'neighbors',
#  'never',
#  'new',
#  'news',
#  'newx',
#  'next',
#  'night',
#  'nola',
#  'north',
#  'nothing',
#  'notice',
#  'npr',
#  'number',
#  'obama',
#  'office',
#  'oh',
#  'ohio',
#  'ok',
#  'old',
#  'omaha',
#  'one',
#  'ones',
#  'open',
#  'org',
#  'orleans',
#  'others',
#  'outside',
#  'ow',
#  'owhnews',
#  'part',
#  'parts',
#  'past',
#  'pay',
#  'people',
#  'personal',
#  'pgemployee',
#  'pic',
#  'place',
#  'places',
#  'plains',
#  'plan',
#  'plant',
#  'play',
#  'please',
#  'point',
#  'political',
#  'politics',
#  'poor',
#  'possible',
#  'post',
#  'posts',
#  'potential',
#  'potus',
#  'power',
#  'pray',
#  'prayers',
#  'prepared',
#  'president',
#  'pretty',
#  'proceeds',
#  'program',
#  'projects',
#  'prone',
#  'protect',
#  'protection',
#  'proud',
#  'provide',
#  'providing',
#  'puerto',
#  'pumps',
#  'put',
#  'rain',
#  'rains',
#  'ranchers',
#  'rather',
#  'reach',
#  'read',
#  'reading',
#  'ready',
#  'real',
#  'realdonaldtrump',
#  'really',
#  'reason',
#  'rebuild',
#  'recede',
#  'recent',
#  'record',
#  'records',
#  'recover',
#  'recovery',
#  'red',
#  'related',
#  'relief',
#  'remember',
#  'repair',
#  'rescue',
#  'residents',
#  'resources',
#  'respect',
#  'response',
#  'rico',
#  'right',
#  'rise',
#  'rising',
#  'risk',
#  'river',
#  'rivers',
#  'road',
#  'roads',
#  'room',
#  'rt',
#  'run',
#  'safe',
#  'said',
#  'saturday',
#  'save',
#  'say',
#  'saying',
#  'says',
#  'school',
#  'se',
#  'sea',
#  'season',
#  'see',
#  'seems',
#  'seen',
#  'senator',
#  'send',
#  'serve',
#  'service',
#  'several',
#  'severe',
#  'share',
#  'shelter',
#  'show',
#  'sign',
#  'since',
#  'slow',
#  'small',
#  'snow',
#  'social',
#  'someone',
#  'something',
#  'soon',
#  'south',
#  'southeast',
#  'southern',
#  'spread',
#  'spring',
#  'st',
#  'stage',
#  'start',
#  'state',
#  'states',
#  'status',
#  'stay',
#  'step',
#  'still',
#  'stop',
#  'store',
#  'storm',
#  'storms',
#  'story',
#  'storyshare',
#  'strong',
#  'students',
#  'suffering',
#  'summer',
#  'sunday',
#  'supplies',
#  'support',
#  'sure',
#  'surrounding',
#  'system',
#  'take',
#  'taken',
#  'taking',
#  'talk',
#  'talking',
#  'team',
#  'tell',
#  'temporary',
#  'texas',
#  'thank',
#  'thanks',
#  'theadvocate',
#  'thing',
#  'things',
#  'think',
#  'thinking',
#  'thousands',
#  'threat',
#  'thursday',
#  'time',
#  'today',
#  'together',
#  'told',
#  'tomorrow',
#  'tonight',
#  'tornado',
#  'tornadoes',
#  'town',
#  'towns',
#  'tropical',
#  'truly',
#  'trump',
#  'trying',
#  'turn',
#  'twitter',
#  'two',
#  'understand',
#  'underwater',
#  'united',
#  'update',
#  'upper',
#  'us',
#  'usa',
#  'use',
#  'user',
#  'utm_campaign',
#  'utm_medium',
#  'utm_source',
#  'valley',
#  'via',
#  'victims',
#  'video',
#  'visit',
#  'volunteer',
#  'volunteers',
#  'vote',
#  'votes',
#  'wait',
#  'waiting',
#  'wake',
#  'wall',
#  'want',
#  'warming',
#  'warning',
#  'warnings',
#  'watch',
#  'watching',
#  'water',
#  'waters',
#  'way',
#  'ways',
#  'weather',
#  'wednesday',
#  'week',
#  'weekend',
#  'weeks',
#  'welcome',
#  'well',
#  'went',
#  'west',
#  'western',
#  'whole',
#  'wide',
#  'winter',
#  'without',
#  'woman',
#  'word',
#  'work',
#  'workers',
#  'working',
#  'world',
#  'worse',
#  'worst',
#  'would',
#  'www',
#  'ya',
#  'year',
#  'years',
#  'yes',
#  'yet',
#  'youtu',
#  'youtube',
#  'zone']

# %%
wts = []

for column in term_df.columns:
    wts.append(term_df[column].max())

# %%
tfidf = pd.DataFrame({'words':term_df.columns, 'weights':wts})

# %%
tfidf.sort_values('weights', ascending=False).head(25)
# Out:
#           words   weights
# 316   insurance  0.895194
# 629         two  0.871861
# 370   louisiana  0.851431
# 657     warning  0.850625
# 272         hay  0.819890
# 663         way  0.793858
# 343        less  0.791575
# 614       today  0.781050
# 484  protection  0.780835
# 593      system  0.775527
# 227      floods  0.747748
# 73          big  0.739815
# 32        alone  0.726232
# 250          go  0.724748
# 654        wall  0.724390
# 118         cnn  0.722314
# 538        says  0.715161
# 275       heard  0.713692
# 373    m25m_org  0.713277
# 658    warnings  0.708709
# 533        said  0.706258
# 77        black  0.703344
# 114     climate  0.700255
# 90   california  0.699120
# 75      billion  0.697620

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df_floods[df_floods['text'].str.contains('hay')][['text']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                        text
# 402  Are there any large flood-affected equine facilities in eastern or northern Nebraska, that is in dire need of good quality grass hay (small square bales) right now??? Please share or contact me ASAP! Can deliver tonight!! Thank you!
# 404  As flood relief continues throughout Nebraska, farmers and ranchers continue to have an emergency need for hay and other supplies.  Extension Service leaders in Kentucky have collected 230+ bales of hay and a semi... https://www.facebook.com/davenemoshow/posts/2786227174737675 …
# 496  BETO is an absolute moron. 100’s of midwestern farmers just “tithed” hay to Nebraska farmers, impacted by flood waters, so they could feed their livestock. That’s what we need, people being kind and helping others in need.
# 504  If any farmer/rancher is donating hay to a guy by the name of CHARLIE HANZEL by Fremont, Nebraska, please don’t do it!! He’s scamming other farmers saying he lost hay in the flood but his land/hay wasn’t touched by the flood. Real survivors need it, not him!! PLEASE SHARE!!
# 656  just saw on TV South Dakota sending tons of hay to flood drenched Nebraska. Farmers need it to feed the cattle. This is USA.
# 693  In North Dakota, we always help others in need. We've had our share of flood disasters & know the devastating needs are plenty & last too long. I'm proud of the farm & ranch families who have donated hay to Nebraska livestock owners to help feed their animals.  #SelflessSaturdayhttps://twitter.com/MortonCountySO/status/1112013044152971264 …
# 696  With feed washed away and #livestock stranded because of historic #floods, the call for help was immediate. Loaded with hay and more, people across #Nebraska and the country have answered that call at a time when the need is tremendous. https://youtu.be/VxAJChAansw  #NebraskaStrong
# 701  Hay, hay, hay. Those folks in Nebraska really need these supplies to help with floods. Way to go \nTruckers!
# 739  Following the historic #Nebraska #floods, the @NCTACurtis will begin accepting donations of hay bales for farmers and ranchers in need. http://bit.ly/2HGcT0i  #NebraskaFlood2019 #NebraskaFloods #NebraskaStrong
# 802  Nebraska National Guard is pushing bales of hay out of helicopters to feed cows stranded by floods caused by climate change, a helicopter using fossil fuels and causing more climate disruption. We need climate action now. #JayInslee #ClimateActionNow
# 834  Nebraska farmers and ranchers need the nations help. We need hay to feed animals affected by the floods. Please share. #NEBRASKASTRONG\nhttps://m.facebook.com/story.php?story_fbid=10216402664570627&id=1576143529 …
# 855  Flood victims in Nebraska need your help - https://www.hayspost.com/2019/03/18/flood-victims-in-nebraska-need-your-help/ …pic.twitter.com/6u7oDPJlWC
# 872  Flood victims in Nebraska need your help https://www.hayspost.com/2019/03/18/flood-victims-in-nebraska-need-your-help/ …

# %%
df_floods[df_floods['text'].str.contains('insurance')][['text']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                